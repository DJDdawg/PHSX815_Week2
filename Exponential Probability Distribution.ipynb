# %%
import random
import numpy as np
from numpy import log as ln
  
N = 100000 #number of random numbers
λ = 1.2 #rate parameter for an exponential distribution

#generate N random numbers between 0 and 1 from a uniform distribution
randnums = []

for i in range(0,N):
    randnums.append(random.uniform(0, 1))
    
#generate N random numbers from an exponential distribution
exprandnums = [-ln(1-x)/λ for x in randnums]


# create histogram of uniform random numbers
n, bins, patches = plt.hist(randnums, 50, density=True, facecolor='g', alpha=0.75)

# plot formating options
plt.xlabel('x')
plt.ylabel('Probability')
plt.title('Uniform Random Number')
plt.grid(True)

# show figure
plt.show()



# create histogram of exponential random numbers
n, bins, patches = plt.hist(exprandnums, 50, density=True, facecolor='g', alpha=0.75)

# plot formating options
plt.xlabel('x')
plt.ylabel('Probability')
plt.title('Random Number from Exponential Distribution')
plt.grid(True)

# show figure
plt.show()
